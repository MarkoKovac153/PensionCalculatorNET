# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Import raw file to clean

# %%
df = pd.read_csv("API_FR.INR.RINR_DS2_en_csv_v2_3139463.csv", skiprows=4)
df.head(5)
# Out:
#                   Country Name Country Code          Indicator Name  \
# 0                        Aruba          ABW  Real interest rate (%)
# 1  Africa Eastern and Southern          AFE  Real interest rate (%)
# 2                  Afghanistan          AFG  Real interest rate (%)
# 3   Africa Western and Central          AFW  Real interest rate (%)
# 4                       Angola          AGO  Real interest rate (%)
#
#   Indicator Code  1960  1961  1962  1963  1964  1965  ...       2015  \
# 0    FR.INR.RINR   NaN   NaN   NaN   NaN   NaN   NaN  ...   0.157925
# 1    FR.INR.RINR   NaN   NaN   NaN   NaN   NaN   NaN  ...        NaN
# 2    FR.INR.RINR   NaN   NaN   NaN   NaN   NaN   NaN  ...  12.252548
# 3    FR.INR.RINR   NaN   NaN   NaN   NaN   NaN   NaN  ...        NaN
# 4    FR.INR.RINR   NaN   NaN   NaN   NaN   NaN   NaN  ...  21.144182
#
#         2016       2017      2018      2019      2020       2021      2022  \
# ...

# %% [markdown]
# Check what columns are there

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', 'Unnamed: 68'],
#       dtype='object')

# %% [markdown]
# Create a new column to contain the latest interest rate figure as not all countries have data from 2023

# %%
df["Latest Interest Rate"] = df.iloc[:, 4:-1].apply(lambda x: x.dropna().iloc[-1] if not x.dropna().empty else np.nan, axis=1)

# %% [markdown]
# Drop unnecessary columns

# %%
df = df.drop(['Indicator Name', 'Indicator Code',
       '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
       '2023', 'Unnamed: 68'], axis=1)

# %%
df.sample(10)
# Out:
#            Country Name Country Code  Latest Interest Rate
# 35               Canada          CAN              0.125752
# 264              Zambia          ZMB             -3.893032
# 103    IDA & IBRD total          IBT                   NaN
# 120          Kazakhstan          KAZ                   NaN
# 112  Iran, Islamic Rep.          IRN              7.861273
# 71              Estonia          EST                   NaN
# 14              Austria          AUT                   NaN
# 38      Channel Islands          CHI                   NaN
# 192         Puerto Rico          PRI                   NaN
# 30             Barbados          BRB              3.818557

# %% [markdown]
# Export the clean data to csv

# %%
df.to_csv("world_bank_interest_rate_cleaned.csv", index=False)
