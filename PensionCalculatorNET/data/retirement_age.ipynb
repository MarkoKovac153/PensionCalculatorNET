# %%
import pandas as pd

# %%
df = pd.read_csv("OECD.ELS.SPD,DSD_PAG@DF_DPS,1.0+all.csv")
df.head(5)
# Out:
#   STRUCTURE                      STRUCTURE_ID             STRUCTURE_NAME  \
# 0  DATAFLOW  OECD.ELS.SPD:DSD_PAG@DF_DPS(1.0)  Design of pension systems
# 1  DATAFLOW  OECD.ELS.SPD:DSD_PAG@DF_DPS(1.0)  Design of pension systems
# 2  DATAFLOW  OECD.ELS.SPD:DSD_PAG@DF_DPS(1.0)  Design of pension systems
# 3  DATAFLOW  OECD.ELS.SPD:DSD_PAG@DF_DPS(1.0)  Design of pension systems
# 4  DATAFLOW  OECD.ELS.SPD:DSD_PAG@DF_DPS(1.0)  Design of pension systems
#
#   ACTION REF_AREA Reference area FREQ Frequency of observation  MEASURE  \
# 0      I      SWE         Sweden    A                   Annual  FRPLF22
# 1      I      CAN         Canada    A                   Annual  CRPLF22
# 2      I      CAN         Canada    A                   Annual  FRPLF22
# 3      I      BEL        Belgium    A                   Annual  FRPLF22
# 4      I      BEL        Belgium    A                   Annual  CRPLF22
#
#                                              Measure  ... TIME_PERIOD  \
# ...

# %%
df = df[df["REF_AREA"] == "GBR"]

# %%
df.columns
# Out:
# Index(['STRUCTURE', 'STRUCTURE_ID', 'STRUCTURE_NAME', 'ACTION', 'REF_AREA',
#        'Reference area', 'FREQ', 'Frequency of observation', 'MEASURE',
#        'Measure', 'UNIT_MEASURE', 'Unit of measure', 'SEX', 'Sex', 'AGE',
#        'Age', 'OPTIONALITY', 'Optionality', 'TIME_PERIOD', 'Time period',
#        'OBS_VALUE', 'Observation value', 'OBS_STATUS', 'Observation status',
#        'UNIT_MULT', 'Unit multiplier', 'DECIMALS', 'Decimals'],
#       dtype='object')

# %%
#df = df[df["MEASURE"] == "CRPLF22"]

# %%
df = df.drop(['STRUCTURE', 'STRUCTURE_ID', 'STRUCTURE_NAME', 'ACTION', 'FREQ', 'Frequency of observation', 'UNIT_MEASURE', 'Unit of measure', 'SEX', 'AGE',
       'Age', 'OPTIONALITY', 'Optionality', 'Time period', 'OBS_STATUS', 'Observation status', 'Observation value', 'TIME_PERIOD',
       'UNIT_MULT', 'Unit multiplier', 'DECIMALS', 'Decimals', "Measure"], axis=1)

# %%
df.head()
# Out:
#     REF_AREA  Reference area  MEASURE     Sex  OBS_VALUE
# 148      GBR  United Kingdom  CRPLF22    Male       66.0
# 149      GBR  United Kingdom  CRPLF22  Female       66.0
# 150      GBR  United Kingdom  FRPLF22    Male       67.0
# 188      GBR  United Kingdom  FRPLF22  Female       67.0

# %%
df = df.rename(columns={"Reference area":"Country Name", "REF_AREA":"Country Code", "OBS_VALUE":"Retirement Age"})
df
# Out:
#     Country Code    Country Name  MEASURE     Sex  Retirement Age
# 148          GBR  United Kingdom  CRPLF22    Male            66.0
# 149          GBR  United Kingdom  CRPLF22  Female            66.0
# 150          GBR  United Kingdom  FRPLF22    Male            67.0
# 188          GBR  United Kingdom  FRPLF22  Female            67.0

# %%
df.to_csv("OECD_retirement_age_gbr_cleaned.csv", index=False)
